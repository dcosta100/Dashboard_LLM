# %%
from sqlalchemy import create_engine
import pandas as pd
from wordcloud import WordCloud
import matplotlib.pyplot as plt

# Staging
server_stg = '34.95.134.241'
database_stg = 'VoistonDb'
username_stg = 'sqlserver'
password_stg = '.KN_mWXA7kxsnat'

# Prod
server_prod = '34.95.157.73'
database_prod = 'VoistonDb'
username_prod = 'sqlserver'
password_prod = 'BF2y4d!.DqR6'
# String de conexão com SQLAlchemy

engine_stg = create_engine(f"mssql+pyodbc://{username_stg}:{password_stg}@{server_stg}/{database_stg}?driver=ODBC+Driver+17+for+SQL+Server")
engine_prod = create_engine(f"mssql+pyodbc://{username_prod}:{password_prod}@{server_prod}/{database_prod}?driver=ODBC+Driver+17+for+SQL+Server")

# %%
# Procedures IDs:

proc = pd.read_sql("""
SELECT *
FROM dbo.ProcedureTypes
""", engine_stg)
unique_procedures_ids = proc.ID.unique().tolist()

# Medications IDs:

med = pd.read_sql("""
                  SELECT * 
                  FROM dbo.Prescriptions
                  """, engine_stg)
unique_medications_id = med.Medication_ID.unique().tolist()

# %%
expectations = [
  {
    "type": "DiagnosisOphthalmological",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "DiagnosisComorbidities",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "FamiliarHistory",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "PreviousOphthalmologicalProcedures",
    "min_expected_measurement": 1,
    "median_expected_measurement": 2,
    "max_expected_measurement": 4,
    "possible_ids": [unique_procedures_ids]
  },
  {
    "type": "MedicationsInUse",
    "min_expected_measurement": 1,
    "median_expected_measurement": 2,
    "max_expected_measurement": 4,
    "possible_ids": [unique_medications_id]
  },
  {
    "type": "MedicationsPrescribed",
    "min_expected_measurement": 1,
    "median_expected_measurement": 2,
    "max_expected_measurement": 4,
    "possible_ids": [unique_medications_id]
  },
  {
    "type": "SlitLamp",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "NeurossensorialOcularEvaluation",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "IntraocularPressure",
    "min_expected_measurement": 1,
    "median_expected_measurement": 2,
    "max_expected_measurement": 10,
    "possible_ids": [79, 478, 544, 546, 548, 550, 552, 553, 554]
  },
  {
    "type": "VisualAcuity",
    "min_expected_measurement": 1,
    "median_expected_measurement": 2,
    "max_expected_measurement": 8,
    "possible_ids": [44, 45, 46, 123655, 123744, 123745, 123755, 123758, 123760, 123922]
  },
  {
    "type": "Refraction",
    "min_expected_measurement": 1,
    "median_expected_measurement": 6,
    "max_expected_measurement": 12,
    "possible_ids": [52, 53, 54, 55, 56, 57, 58, 475, 476, 477, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 618, 619, 782, 123599, 123605, 123657, 123668, 123764, 123765, 123766, 123767, 123768, 123769, 124772, 124773, 124774, 124848]
  },
  {
    "type": "Cid",
    "min_expected_measurement": 1,
    "median_expected_measurement": 2,
    "max_expected_measurement": 4,
    "possible_ids": [123772, 123653]
  },
  {
    "type": "MedicalConduct",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "RefractionOnly",
    "min_expected_measurement": 1,
    "median_expected_measurement": 6,
    "max_expected_measurement": 12,
    "possible_ids": [52, 53, 54, 55, 56, 57, 58, 475, 476, 477, 485, 486, 487, 488, 489, 490, 491, 492, 493, 494, 495, 496, 497, 498, 499, 618, 619, 782, 123599, 123605, 123657, 123668, 123764, 123765, 123766, 123767, 123768, 123769, 124772, 124773, 124774]
  },
  {
    "type": "ExaminationReport",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "SurgicalDescription",
    "min_expected_measurement": 1,
    "median_expected_measurement": 2,
    "max_expected_measurement": 4,
    "possible_ids": [unique_procedures_ids]
  },
  {
    "type": "AnesthesiaRecord",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "MedicalLeaveCertificate",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "MedicalReport",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "PreopEvaluation",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "InformedConsent",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "PatientWish",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  },
  {
    "type": "TreatmentContraindication",
    "min_expected_measurement": 0,
    "median_expected_measurement": 0,
    "max_expected_measurement": 0,
    "possible_ids": []
  }
]

# Salvar como mapa_expectativas.json
import json

with open("mapa_expectativas_nova.json", "w") as f:
    json.dump(expectations, f)
